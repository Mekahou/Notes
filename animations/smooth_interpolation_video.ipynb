# %%
import numpy as np  # NumPy for arrays
import torch  # PyTorch for tensors
import torch.nn as nn  # Neural network module
from torch.utils.data import DataLoader, TensorDataset  # Data loading utilities
import torch.optim as optim
import matplotlib.pyplot as plt  # For plotting
from matplotlib import cm  # Colormap for plots

# %% [markdown]
# # Data Generating Process

# %%
def dgp_y(x):

    y = 2*(1-torch.exp(-torch.abs(x+torch.sin(x**2))))
    return y

# %%
x_train = torch.arange(0,6,0.5).unsqueeze(dim=1)
y_train = dgp_y(x_train)
x_test = torch.arange(0,6,0.01).unsqueeze(dim=1)
y_test = dgp_y(x_test)

# %%
plt.scatter(x_train,y_train, color = "r")
plt.plot(x_test,y_test)
plt.title("Data Generating Process")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# # Neural Network Approximation

# %% [markdown]
# ## Defining the neural network

# %%
class NN(nn.Module):
    def __init__(self,
                 dim_hidden = 128,):
        super().__init__()
        torch.manual_seed(123) # fixing the seed
        self.dim_hidden= dim_hidden
        
        self.y = nn.Sequential(
            nn.Linear(1, dim_hidden),
            nn.ReLU(),
            nn.Linear(dim_hidden, 1),
        )

    def forward(self, x):
        return self.y(x)

# %%
def count_parameters(model):
    """
    Counts the number of trainable weights and biases in the neural network.

    Parameters:
    - model: The PyTorch model

    Returns:
    - total_params: The total number of parameters (weights + biases)
    """
    total_params = 0
    for param in model.parameters():
        total_params += param.numel()  # numel() returns the total number of elements (weights/biases) in the parameter
    return total_params

# %%
def train_lbfgs(model, epochs=100, lr=0.1):
    """
    Trains the input model using LBFGS optimizer.

    Parameters:
    - model: PyTorch model to be trained
    - x_train: Training data (input)
    - y_train: Training data (target output)
    - epochs: Number of training epochs (default is 100)
    - lr: Learning rate for the LBFGS optimizer (default is 0.1)

    Returns:
    - model: The trained model
    - loss_history: A list of loss values recorded during training
    """
    
    # Define the loss function (Mean Squared Error)
    criterion = nn.MSELoss()
    
    # Define the LBFGS optimizer
    optimizer = optim.LBFGS(model.parameters(), lr=lr)
    #optimizer = optim.LBFGS(model.parameters(),lr=lr, line_search_fn="strong_wolfe")
    # Closure function required by LBFGS
    def closure():
        optimizer.zero_grad()  # Zero out gradients
        output = model(x_train)  # Forward pass
        loss = criterion(output, y_train)  # Compute loss
        loss.backward()  # Backpropagate to calculate gradients
        return loss

    # List to store loss values for each epoch
    loss_history = []

    # Training loop
    for epoch in range(epochs):
        optimizer.step(closure)  # Perform LBFGS step

        # Record loss every epoch
        with torch.no_grad():
            output = model(x_train)
            loss = criterion(output, y_train)
            loss_history.append(loss.item())
            if epoch % 10 == 0:  # Print loss every 10 epochs
                print(f'Epoch {epoch}: Loss = {loss.item()}')

    return model, loss_history

# %% [markdown]
# ## Generating the list for train and test loss

# %%
uniform_mesh = torch.linspace(0, 1, steps=100)
mesh_dim_hidden = (uniform_mesh**3) * 5000+1
mesh_dim_hidden = torch.unique(mesh_dim_hidden.round().int())
len(mesh_dim_hidden)
train_loss_vec = torch.zeros(len(mesh_dim_hidden))
test_loss_vec = torch.zeros(len(mesh_dim_hidden))

# %%
"""
for i,dim in enumerate(mesh_dim_hidden):
    print(i)
    model = NN(dim_hidden = dim)
    trained_model, loss_history =  train_lbfgs(model , epochs=100, lr=0.1)
    train_loss_vec[i] = loss_history[-1]
    err_test = (model(x_test).detach()-y_test)**2
    test_loss_vec[i] = err_test.mean()
"""
# Out:
# '\nfor i,dim in enumerate(mesh_dim_hidden):\n    print(i)\n    model = NN(dim_hidden = dim)\n    trained_model, loss_history =  train_lbfgs(model , epochs=100, lr=0.1)\n    train_loss_vec[i] = loss_history[-1]\n    err_test = (model(x_test).detach()-y_test)**2\n    test_loss_vec[i] = err_test.mean()\n'

# %%
fontsize= 18
ticksize = 14
figsize = (15, 10)
params = {'font.family':'serif',
    "figure.figsize":figsize,
    'figure.dpi': 80,
    'figure.edgecolor': 'k',
    'font.size': fontsize,
    'axes.labelsize': fontsize,
    'axes.titlesize': fontsize,
    'xtick.labelsize': ticksize,
    'ytick.labelsize': ticksize
}
plt.rcParams.update(params)

# %%
model_1 = NN(dim_hidden = 10)
print(count_parameters(model_1))

# Train the model using LBFGS
trained_model_1, loss_history_1 = train_lbfgs(model_1 , epochs=100, lr=0.1)

y_hat_1 = trained_model_1(x_test).detach()
# Out:
# 31
# Epoch 0: Loss = 0.2866058647632599
# Epoch 10: Loss = 0.011162147857248783
# Epoch 20: Loss = 0.011162147857248783
# Epoch 30: Loss = 0.011162147857248783
# Epoch 40: Loss = 0.011162147857248783
# Epoch 50: Loss = 0.011162147857248783
# Epoch 60: Loss = 0.011162147857248783
# Epoch 70: Loss = 0.011162147857248783
# Epoch 80: Loss = 0.011162147857248783
# Epoch 90: Loss = 0.011162147857248783

# %%
model_2 = NN(dim_hidden = 800)
print(count_parameters(model_2))

# Train the model using LBFGS
trained_model_2, loss_history_2 = train_lbfgs(model_2 , epochs=100, lr=0.1)

y_hat_2 = trained_model_2(x_test).detach()
# Out:
# 2401
# Epoch 0: Loss = 0.29526039958000183
# Epoch 10: Loss = 0.00012595653242897242
# Epoch 20: Loss = 0.001127092749811709
# Epoch 30: Loss = 4.4621378037845716e-05
# Epoch 40: Loss = 4.4569242163561285e-05
# Epoch 50: Loss = 4.523578172666021e-05
# Epoch 60: Loss = 4.4872198486700654e-05
# Epoch 70: Loss = 4.4456621253630146e-05
# Epoch 80: Loss = 4.502884985413402e-05
# Epoch 90: Loss = 4.48497012257576e-05

# %%
model_3 = NN(dim_hidden = 4000)
print(count_parameters(model_3))

# Train the model using LBFGS
trained_model_3, loss_history_3 = train_lbfgs(model_3 , epochs=100, lr=0.1)

y_hat_3 = trained_model_3(x_test).detach()
# Out:
# 12001
# Epoch 0: Loss = 0.3169228136539459
# Epoch 10: Loss = 0.001923350035212934
# Epoch 20: Loss = 3.476898928056471e-05
# Epoch 30: Loss = 6.185622964949289e-07
# Epoch 40: Loss = 6.155600544843765e-07
# Epoch 50: Loss = 6.154109541967046e-07
# Epoch 60: Loss = 6.154109541967046e-07
# Epoch 70: Loss = 6.154109541967046e-07
# Epoch 80: Loss = 6.154109541967046e-07
# Epoch 90: Loss = 6.154109541967046e-07

# %%
plt.subplot(2, 2 , 1)
plt.scatter(x_train,y_train, color = "r", label = "Training Data")
plt.xlabel(r"$X$")
plt.ylabel(r"$Y$")
plt.ylim(-0.5, 2.1)  
plt.legend(loc='lower right')

plt.subplot(2, 2 , 2)
plt.scatter(x_train,y_train, color = "r", label = "Training Data")
plt.plot(x_test, y_hat_1, color = "b", label = r"# of Parameters= 31")
plt.xlabel(r"$X$")
plt.ylabel(r"$Y$")
plt.ylim(-0.5, 2.1) 
plt.legend(loc='best')

plt.subplot(2, 2, 3)
plt.scatter(x_train,y_train, color = "r", label = "Training Data")
plt.plot(x_test, y_hat_2, color = "b",  label = "# of Parameters= 2.4 K")
plt.xlabel(r"$X$")
plt.ylabel(r"$Y$")
plt.ylim(-0.5, 2.1)  
plt.legend(loc='best')

plt.subplot(2, 2, 4)
plt.scatter(x_train,y_train, color = "r", label = "Training Data")
plt.plot(x_test, y_hat_3, color = "b", label = "# of Parameters= 12 K")
plt.xlabel(r"$X$")
plt.ylabel(r"$Y$")
plt.ylim(-0.5, 2.1) 
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# # Making the animation

# %%
# Building the number of nodes array
# 1) 1 to 200 step 1
nodes_1 = np.arange(1, 201, 1)

# 2) 200 to 1000 step 10
nodes_2 = np.arange(200, 1001, 5)

# 3) 1000 to 5000 step 50
nodes_3 = np.arange(1000, 8001, 50)

# Combine all parts
nodes = np.unique(np.concatenate([nodes_1, nodes_2, nodes_3]))

# %%
results_list = []
num_params_list = []

for node in nodes:
    print(node)
    
    model_node = NN(dim_hidden=node)  # create a fresh model for this node
    trained_model_node, _ = train_lbfgs(model_node, epochs=100, lr=0.1)
    
    y_hat_node = trained_model_node(x_test).detach().squeeze()
    
    # Check for NaN
    if np.isnan(y_hat_node).any():
        print(f"Skipping node {node} due to NaN in predictions")
        continue  # skip saving this node
    
    # Save results
    results_list.append(y_hat_node)
    params_num = count_parameters(model_node)
    num_params_list.append(params_num)

# Convert lists to arrays at the end
results_array = np.array(results_list)
num_params_array = np.array(num_params_list)
# Out:
# 1
# Epoch 0: Loss = 0.07688958197832108
# Epoch 10: Loss = 0.024129988625645638
# Epoch 20: Loss = 0.024129988625645638
# Epoch 30: Loss = 0.024129988625645638
# Epoch 40: Loss = 0.024129988625645638
# Epoch 50: Loss = 0.024129988625645638
# Epoch 60: Loss = 0.024129988625645638
# Epoch 70: Loss = 0.024129988625645638
# Epoch 80: Loss = 0.024129988625645638
# Epoch 90: Loss = 0.024129988625645638
# 2
# Epoch 0: Loss = 0.19165705144405365
# Epoch 10: Loss = 0.1380062848329544
# Epoch 20: Loss = 0.1380062848329544
# Epoch 30: Loss = 0.1380062848329544
# Epoch 40: Loss = 0.1380062848329544
# Epoch 50: Loss = 0.1380062848329544
# Epoch 60: Loss = 0.1380062848329544
# Epoch 70: Loss = 0.1380062848329544
# Epoch 80: Loss = 0.1380062848329544
# Epoch 90: Loss = 0.1380062848329544
# 3
# Epoch 0: Loss = 0.06243492662906647
# Epoch 10: Loss = 0.021647324785590172
# Epoch 20: Loss = 0.021647324785590172
# Epoch 30: Loss = 0.021647324785590172
# Epoch 40: Loss = 0.021647324785590172
# Epoch 50: Loss = 0.021647324785590172
# Epoch 60: Loss = 0.021647324785590172
# Epoch 70: Loss = 0.021647324785590172
# Epoch 80: Loss = 0.021647324785590172
# Epoch 90: Loss = 0.021647324785590172
# 4
# Epoch 0: Loss = 0.14567677676677704
# Epoch 10: Loss = 0.011162154376506805
# Epoch 20: Loss = 0.011162154376506805
# Epoch 30: Loss = 0.011162154376506805
# Epoch 40: Loss = 0.011162154376506805
# Epoch 50: Loss = 0.011162154376506805
# Epoch 60: Loss = 0.011162154376506805
# Epoch 70: Loss = 0.011162154376506805
# Epoch 80: Loss = 0.011162154376506805
# Epoch 90: Loss = 0.011162154376506805
# 5
# Epoch 0: Loss = 0.1273690164089203
# Epoch 10: Loss = 0.02164732664823532
# Epoch 20: Loss = 0.021647321060299873
# Epoch 30: Loss = 0.021647321060299873
# Epoch 40: Loss = 0.021647321060299873
# Epoch 50: Loss = 0.021647321060299873
# Epoch 60: Loss = 0.021647321060299873
# Epoch 70: Loss = 0.021647321060299873
# Epoch 80: Loss = 0.021647321060299873
# Epoch 90: Loss = 0.021647321060299873
# 6
# Epoch 0: Loss = 0.254687637090683
# Epoch 10: Loss = 0.1380062848329544
# Epoch 20: Loss = 0.1380062848329544
# Epoch 30: Loss = 0.1380062848329544
# Epoch 40: Loss = 0.1380062848329544
# Epoch 50: Loss = 0.1380062848329544
# Epoch 60: Loss = 0.1380062848329544
# Epoch 70: Loss = 0.1380062848329544
# Epoch 80: Loss = 0.1380062848329544
# Epoch 90: Loss = 0.1380062848329544
# 7
# Epoch 0: Loss = 0.1579483449459076
# Epoch 10: Loss = 0.011162144131958485
# Epoch 20: Loss = 0.011162144131958485
# Epoch 30: Loss = 0.011162144131958485
# Epoch 40: Loss = 0.011162144131958485
# Epoch 50: Loss = 0.011162144131958485
# Epoch 60: Loss = 0.011162144131958485
# Epoch 70: Loss = 0.011162144131958485
# Epoch 80: Loss = 0.011162144131958485
# Epoch 90: Loss = 0.011162144131958485
# 8
# Epoch 0: Loss = 0.21176446974277496
# Epoch 10: Loss = 0.01116212084889412
# Epoch 20: Loss = 0.01116212084889412
# Epoch 30: Loss = 0.01116212084889412
# Epoch 40: Loss = 0.01116212084889412
# Epoch 50: Loss = 0.01116212084889412
# Epoch 60: Loss = 0.01116212084889412
# Epoch 70: Loss = 0.01116212084889412
# Epoch 80: Loss = 0.01116212084889412
# Epoch 90: Loss = 0.01116212084889412
# 9
# Epoch 0: Loss = 0.12993302941322327
# Epoch 10: Loss = 0.011162139475345612
# Epoch 20: Loss = 0.011162139475345612
# Epoch 30: Loss = 0.011162139475345612
# Epoch 40: Loss = 0.011162139475345612
# Epoch 50: Loss = 0.011162139475345612
# Epoch 60: Loss = 0.011162139475345612
# Epoch 70: Loss = 0.011162139475345612
# Epoch 80: Loss = 0.011162139475345612
# Epoch 90: Loss = 0.011162139475345612
# 10
# Epoch 0: Loss = 0.2866058647632599
# Epoch 10: Loss = 0.011162147857248783
# Epoch 20: Loss = 0.011162147857248783
# Epoch 30: Loss = 0.011162147857248783
# Epoch 40: Loss = 0.011162147857248783
# Epoch 50: Loss = 0.011162147857248783
# Epoch 60: Loss = 0.011162147857248783
# Epoch 70: Loss = 0.011162147857248783
# Epoch 80: Loss = 0.011162147857248783
# Epoch 90: Loss = 0.011162147857248783
# 11
# Epoch 0: Loss = 0.21551896631717682
# Epoch 10: Loss = 0.01116215530782938
# Epoch 20: Loss = 0.01116215530782938
# Epoch 30: Loss = 0.01116215530782938
# Epoch 40: Loss = 0.01116215530782938
# Epoch 50: Loss = 0.01116215530782938
# Epoch 60: Loss = 0.01116215530782938
# Epoch 70: Loss = 0.01116215530782938
# Epoch 80: Loss = 0.01116215530782938
# Epoch 90: Loss = 0.01116215530782938
# 12
# Epoch 0: Loss = 0.34995830059051514
# Epoch 10: Loss = 0.011162140406668186
# Epoch 20: Loss = 0.011162140406668186
# Epoch 30: Loss = 0.011162140406668186
# Epoch 40: Loss = 0.011162140406668186
# Epoch 50: Loss = 0.011162140406668186
# Epoch 60: Loss = 0.011162140406668186
# Epoch 70: Loss = 0.011162140406668186
# Epoch 80: Loss = 0.011162140406668186
# Epoch 90: Loss = 0.011162140406668186
# 13
# Epoch 0: Loss = 0.23657940328121185
# Epoch 10: Loss = 0.011162158101797104
# Epoch 20: Loss = 0.011162158101797104
# Epoch 30: Loss = 0.011162158101797104
# Epoch 40: Loss = 0.011162158101797104
# Epoch 50: Loss = 0.011162158101797104
# Epoch 60: Loss = 0.011162158101797104
# Epoch 70: Loss = 0.011162158101797104
# Epoch 80: Loss = 0.011162158101797104
# Epoch 90: Loss = 0.011162158101797104
# 14
# Epoch 0: Loss = 0.22355251014232635
# Epoch 10: Loss = 0.011162146925926208
# Epoch 20: Loss = 0.01116214320063591
# Epoch 30: Loss = 0.01116214320063591
# Epoch 40: Loss = 0.01116214320063591
# Epoch 50: Loss = 0.01116214320063591
# Epoch 60: Loss = 0.01116214320063591
# Epoch 70: Loss = 0.01116214320063591
# Epoch 80: Loss = 0.01116214320063591
# Epoch 90: Loss = 0.01116214320063591
# 15
# Epoch 0: Loss = 0.23067130148410797
# Epoch 10: Loss = 0.009376196190714836
# Epoch 20: Loss = 0.009376207366585732
# Epoch 30: Loss = 0.009376207366585732
# Epoch 40: Loss = 0.009376207366585732
# Epoch 50: Loss = 0.009376207366585732
# Epoch 60: Loss = 0.009376207366585732
# Epoch 70: Loss = 0.009376207366585732
# Epoch 80: Loss = 0.009376207366585732
# Epoch 90: Loss = 0.009376207366585732
# 16
# Epoch 0: Loss = 0.13799983263015747
# Epoch 10: Loss = 0.010304185561835766
# Epoch 20: Loss = 0.010304178111255169
# Epoch 30: Loss = 0.010304178111255169
# Epoch 40: Loss = 0.010304178111255169
# Epoch 50: Loss = 0.010304178111255169
# Epoch 60: Loss = 0.010304178111255169
# Epoch 70: Loss = 0.010304178111255169
# Epoch 80: Loss = 0.010304178111255169
# Epoch 90: Loss = 0.010304178111255169
# 17
# Epoch 0: Loss = 0.24395431578159332
# 24
# Epoch 0: Loss = 0.24191488325595856
# Epoch 10: Loss = 0.010311097837984562
# Epoch 20: Loss = 0.010311097837984562
# Epoch 30: Loss = 0.010311097837984562
# Epoch 40: Loss = 0.010311097837984562
# Epoch 50: Loss = 0.010311097837984562
# Epoch 60: Loss = 0.010311097837984562
# Epoch 70: Loss = 0.010311097837984562
# Epoch 80: Loss = 0.010311097837984562
# Epoch 90: Loss = 0.010311097837984562
# 25
# Epoch 0: Loss = 0.4335037171840668
# Epoch 10: Loss = 0.00012387313472572714
# Epoch 20: Loss = 0.00011682428885251284
# Epoch 30: Loss = 0.00011682428885251284
# Epoch 40: Loss = 0.00011682428885251284
# Epoch 50: Loss = 0.00011682428885251284
# Epoch 60: Loss = 0.00011682428885251284
# Epoch 70: Loss = 0.00011682428885251284
# Epoch 80: Loss = 0.00011682428885251284
# Epoch 90: Loss = 0.00011682428885251284
# 26
# Epoch 0: Loss = 0.15819473564624786
# Epoch 10: Loss = 0.011162158101797104
# Epoch 20: Loss = 0.011162142269313335
# Epoch 30: Loss = 0.011162142269313335
# Epoch 40: Loss = 0.011162142269313335
# Epoch 50: Loss = 0.011162142269313335
# Epoch 60: Loss = 0.011162142269313335
# Epoch 70: Loss = 0.011162142269313335
# Epoch 80: Loss = 0.011162142269313335
# Epoch 90: Loss = 0.011162142269313335
# 27
# Epoch 0: Loss = 0.2510581314563751
# Epoch 10: Loss = 0.01116215530782938
# Epoch 20: Loss = 0.01116214320063591
# Epoch 30: Loss = 0.01116214320063591
# Epoch 40: Loss = 0.01116214320063591
# Epoch 50: Loss = 0.01116214320063591
# Epoch 60: Loss = 0.01116214320063591
# Epoch 70: Loss = 0.01116214320063591
# Epoch 80: Loss = 0.01116214320063591
# Epoch 90: Loss = 0.01116214320063591
# 28
# Epoch 0: Loss = 0.2514149248600006
# Epoch 10: Loss = 0.011048790067434311
# Epoch 20: Loss = 0.011048787273466587
# Epoch 30: Loss = 0.011048787273466587
# Epoch 40: Loss = 0.011048787273466587
# Epoch 50: Loss = 0.011048787273466587
# Epoch 60: Loss = 0.011048787273466587
# Epoch 70: Loss = 0.011048787273466587
# Epoch 80: Loss = 0.011048787273466587
# Epoch 90: Loss = 0.011048787273466587
# 29
# Epoch 0: Loss = 0.3088661730289459
# Epoch 10: Loss = 0.01031110156327486
# Epoch 20: Loss = 0.010311097837984562
# Epoch 30: Loss = 0.010311097837984562
# Epoch 40: Loss = 0.010311097837984562
# Epoch 50: Loss = 0.010311097837984562
# Epoch 60: Loss = 0.010311097837984562
# Epoch 70: Loss = 0.010311097837984562
# Epoch 80: Loss = 0.010311097837984562
# Epoch 90: Loss = 0.010311097837984562
# 30
# Epoch 0: Loss = 0.2447637915611267
# Epoch 10: Loss = 0.010311112739145756
# Epoch 20: Loss = 0.01031110342592001
# Epoch 30: Loss = 0.01031110342592001
# Epoch 40: Loss = 0.01031110342592001
# Epoch 50: Loss = 0.01031110342592001
# Epoch 60: Loss = 0.01031110342592001
# Epoch 70: Loss = 0.01031110342592001
# Epoch 80: Loss = 0.01031110342592001
# Epoch 50: Loss = nan
# Epoch 60: Loss = nan
# Epoch 70: Loss = nan
# Epoch 80: Loss = nan
# Epoch 90: Loss = nan
# Skipping node 44 due to NaN in predictions
# 45
# Epoch 0: Loss = 0.2606810927391052
# Epoch 10: Loss = 0.00011932029156014323
# Epoch 20: Loss = 0.00011683199409162626
# Epoch 30: Loss = 0.00011683199409162626
# Epoch 40: Loss = 0.00011683199409162626
# Epoch 50: Loss = 0.00011683199409162626
# Epoch 60: Loss = 0.00011683199409162626
# Epoch 70: Loss = 0.00011683199409162626
# Epoch 80: Loss = 0.00011683199409162626
# Epoch 90: Loss = 0.00011683199409162626
# 46
# Epoch 0: Loss = 0.24518711864948273
# Epoch 10: Loss = 0.010304177179932594
# Epoch 20: Loss = 0.010304177179932594
# Epoch 30: Loss = 0.010304177179932594
# Epoch 40: Loss = 0.010304177179932594
# Epoch 50: Loss = 0.010304177179932594
# Epoch 60: Loss = 0.010304177179932594
# Epoch 70: Loss = 0.010304177179932594
# Epoch 80: Loss = 0.010304177179932594
# Epoch 90: Loss = 0.010304177179932594
# 47
# Epoch 0: Loss = 0.25340670347213745
# Epoch 10: Loss = nan
# Epoch 20: Loss = nan
# Epoch 30: Loss = nan
# Epoch 40: Loss = nan
# Epoch 50: Loss = nan
# Epoch 60: Loss = nan
# Epoch 70: Loss = nan
# Epoch 80: Loss = nan
# Epoch 90: Loss = nan
# Skipping node 47 due to NaN in predictions
# 48
# Epoch 0: Loss = 0.23270605504512787
# Epoch 10: Loss = 0.010304621420800686
# Epoch 20: Loss = 0.010304597206413746
# Epoch 30: Loss = 0.010304597206413746
# Epoch 40: Loss = 0.010304597206413746
# Epoch 50: Loss = 0.010304597206413746
# Epoch 60: Loss = 0.010304597206413746
# Epoch 70: Loss = 0.010304597206413746
# Epoch 80: Loss = 0.010304597206413746
# Epoch 90: Loss = 0.010304597206413746
# 49
# Epoch 0: Loss = 0.30929186940193176
# Epoch 10: Loss = 0.0057664052583277225
# Epoch 20: Loss = 0.00011682188051054254
# Epoch 30: Loss = 0.00011682359763653949
# Epoch 40: Loss = 0.00011682359763653949
# Epoch 50: Loss = 0.00011682359763653949
# Epoch 60: Loss = 0.00011682359763653949
# Epoch 70: Loss = 0.00011682359763653949
# Epoch 80: Loss = 0.00011682359763653949
# Epoch 90: Loss = 0.00011682359763653949
# 50
# Epoch 0: Loss = 0.36934077739715576
# Epoch 10: Loss = 0.003826836356893182
# Epoch 20: Loss = 0.0033394440542906523
# Epoch 30: Loss = 0.0033394440542906523
# Epoch 40: Loss = 0.0033394440542906523
# Epoch 50: Loss = 0.0033394440542906523
# Epoch 60: Loss = 0.0033394440542906523
# Epoch 70: Loss = 0.0033394440542906523
# Epoch 80: Loss = 0.0033394440542906523
# Epoch 90: Loss = 0.0033394440542906523
# 51
# Epoch 0: Loss = 0.3197050094604492
# Epoch 10: Loss = 0.000133005523821339
# Epoch 20: Loss = 0.00011682361946441233
# Epoch 30: Loss = 0.00011682361946441233
# Epoch 40: Loss = 0.00011682361946441233
# Epoch 50: Loss = 0.00011682361946441233
# Epoch 60: Loss = 0.00011682361946441233
# Epoch 70: Loss = 0.00011682361946441233
# Epoch 80: Loss = 0.00011682361946441233
# Epoch 90: Loss = 0.00011682361946441233
# 52
# Epoch 0: Loss = 0.3292976915836334
# Epoch 10: Loss = 0.006664779037237167
# Epoch 20: Loss = nan
# Epoch 30: Loss = nan
# Epoch 40: Loss = nan
# Epoch 50: Loss = nan
# Epoch 60: Loss = nan
# Epoch 70: Loss = nan
# Epoch 80: Loss = nan
# Epoch 90: Loss = nan
# Skipping node 52 due to NaN in predictions
# 53
# Epoch 0: Loss = 0.30576372146606445
# Epoch 10: Loss = 0.0009285308769904077
# Epoch 20: Loss = 0.00011682580225169659
# Epoch 30: Loss = 0.00011682580225169659
# Epoch 40: Loss = 0.00011682580225169659
# Epoch 50: Loss = 0.00011682580225169659
# Epoch 60: Loss = 0.00011682580225169659
# Epoch 70: Loss = 0.00011682580225169659
# Epoch 80: Loss = 0.00011682580225169659
# Epoch 90: Loss = 0.00011682580225169659
# 54
# Epoch 0: Loss = 0.33215007185935974
# Epoch 10: Loss = 0.00023233807587530464
# Epoch 20: Loss = 0.00010680951527319849
# Epoch 30: Loss = 0.00010679807019187137
# Epoch 40: Loss = 0.00010679807019187137
# Epoch 50: Loss = 0.00010679807019187137
# Epoch 60: Loss = 0.00010679807019187137
# Epoch 70: Loss = 0.00010679807019187137
# Epoch 80: Loss = 0.00010679807019187137
# Epoch 90: Loss = 0.00010679807019187137
# 55
# Epoch 0: Loss = 0.18256115913391113
# Epoch 10: Loss = 0.0012252219021320343
# Epoch 20: Loss = 0.00042125085019506514
# Epoch 30: Loss = 0.00042125085019506514
# Epoch 40: Loss = 0.00042125085019506514
# Epoch 50: Loss = 0.00042125085019506514
# Epoch 60: Loss = 0.00042125085019506514
# Epoch 70: Loss = 0.00042125085019506514
# Epoch 80: Loss = 0.00042125085019506514
# Epoch 90: Loss = 0.00042125085019506514
# 56
# Epoch 0: Loss = 0.18948101997375488
# Epoch 10: Loss = 0.01030422281473875
# Epoch 20: Loss = 0.010304133407771587
# Epoch 30: Loss = 0.010304133407771587
# Epoch 40: Loss = 0.010304133407771587
# Epoch 50: Loss = 0.010304133407771587
# Epoch 60: Loss = 0.010304133407771587
# Epoch 70: Loss = 0.010304133407771587
# Epoch 80: Loss = 0.010304133407771587
# Epoch 90: Loss = 0.010304133407771587
# 57
# Epoch 0: Loss = 0.23659920692443848
# Epoch 10: Loss = 0.0001478775084251538
# Epoch 20: Loss = 0.00011682533659040928
# Epoch 30: Loss = 0.00011682533659040928
# Epoch 40: Loss = 0.00011682533659040928
# Epoch 50: Loss = 0.00011682533659040928
# Epoch 60: Loss = 0.00011682533659040928
# Epoch 70: Loss = 0.00011682533659040928
# Epoch 80: Loss = 0.00011682533659040928
# Epoch 90: Loss = 0.00011682533659040928
# 58
# Epoch 0: Loss = 0.28622564673423767
# Epoch 10: Loss = 0.001906618825159967
# Epoch 20: Loss = 0.00011682465992635116
# Epoch 30: Loss = 0.00011682465992635116
# Epoch 40: Loss = 0.00011682465992635116
# Epoch 50: Loss = 0.00011682465992635116
# Epoch 60: Loss = 0.00011682465992635116
# Epoch 70: Loss = 0.00011682465992635116
# Epoch 80: Loss = 0.00011682465992635116
# Epoch 90: Loss = 0.00011682465992635116
# 59
# Epoch 0: Loss = 0.24777095019817352
# Epoch 10: Loss = 0.0031103685032576323
# Epoch 20: Loss = 0.00011682684998959303
# Epoch 30: Loss = 0.00011682230979204178
# Epoch 40: Loss = 0.00011682230979204178
# Epoch 50: Loss = 0.00011682230979204178
# Epoch 60: Loss = 0.00011682230979204178
# Epoch 70: Loss = 0.00011682230979204178
# Epoch 80: Loss = 0.00011682230979204178
# Epoch 90: Loss = 0.00011682230979204178
# 60
# Epoch 0: Loss = 0.1714920997619629
# Epoch 10: Loss = nan
# Epoch 20: Loss = nan
# Epoch 30: Loss = nan
# Epoch 40: Loss = nan
# Epoch 50: Loss = nan
# Epoch 60: Loss = nan
# Epoch 70: Loss = nan
# Epoch 80: Loss = nan
# Epoch 90: Loss = nan
# Skipping node 60 due to NaN in predictions
# 61
# Epoch 0: Loss = 0.22156955301761627
# Epoch 10: Loss = 0.0005680957110598683
# Epoch 20: Loss = 8.370575960725546e-05
# Epoch 30: Loss = 8.370575960725546e-05
# Epoch 40: Loss = 8.370575960725546e-05
# Epoch 50: Loss = 8.370575960725546e-05
# Epoch 60: Loss = 8.370575960725546e-05
# Epoch 70: Loss = 8.370575960725546e-05
# Epoch 80: Loss = 8.370575960725546e-05
# Epoch 90: Loss = 8.370575960725546e-05
# 62
# Epoch 0: Loss = 0.3350912630558014
# Epoch 10: Loss = nan
# Epoch 20: Loss = nan
# Epoch 30: Loss = nan
# Epoch 40: Loss = nan
# Epoch 50: Loss = nan
# Epoch 60: Loss = nan
# Epoch 70: Loss = nan
# Epoch 80: Loss = nan
# Epoch 90: Loss = nan
# Skipping node 62 due to NaN in predictions
# 63
# Epoch 0: Loss = 0.2325703650712967
# Epoch 10: Loss = 0.0001286874758079648
# Epoch 20: Loss = 0.00011682140757329762
# Epoch 30: Loss = 0.00011682140757329762
# Epoch 40: Loss = 0.00011682140757329762
# Epoch 50: Loss = 0.00011682140757329762
# Epoch 60: Loss = 0.00011682140757329762
# Epoch 70: Loss = 0.00011682140757329762
# Epoch 80: Loss = 0.00011682140757329762
# Epoch 90: Loss = 0.00011682140757329762
# 64
# Epoch 0: Loss = 0.28934749960899353
# Epoch 10: Loss = nan
# Epoch 20: Loss = nan
# Epoch 30: Loss = nan
# Epoch 40: Loss = nan
# Epoch 50: Loss = nan
# Epoch 60: Loss = nan
# Epoch 70: Loss = nan
# Epoch 80: Loss = nan
# Epoch 90: Loss = nan
# Skipping node 64 due to NaN in predictions
# 65
# Epoch 0: Loss = 0.2891644239425659
# Epoch 10: Loss = 0.0028448961675167084
# Epoch 20: Loss = 0.00011682481272146106
# Epoch 30: Loss = 0.00011682368494803086
# Epoch 40: Loss = 0.00011682368494803086
# Epoch 50: Loss = 0.00011682368494803086
# Epoch 60: Loss = 0.00011682368494803086
# Epoch 70: Loss = 0.00011682368494803086
# Epoch 80: Loss = 0.00011682368494803086
# Epoch 90: Loss = 0.00011682368494803086
# 66
# Epoch 0: Loss = 0.2419087290763855
# Epoch 10: Loss = 0.004120009019970894
# Epoch 20: Loss = nan
# Epoch 30: Loss = nan
# Epoch 40: Loss = nan
# Epoch 50: Loss = nan
# Epoch 60: Loss = nan
# Epoch 70: Loss = nan
# Epoch 80: Loss = nan
# Epoch 90: Loss = nan
# Skipping node 66 due to NaN in predictions
# 67
# Epoch 0: Loss = 0.25607606768608093
# Epoch 10: Loss = 0.0007892607827670872
# Epoch 20: Loss = 7.755341357551515e-05
# Epoch 30: Loss = 7.555583579232916e-05
# Epoch 40: Loss = 7.555710180895403e-05
# Epoch 50: Loss = 7.555710180895403e-05
# Epoch 60: Loss = 7.555710180895403e-05
# Epoch 70: Loss = 7.555710180895403e-05
# Epoch 80: Loss = 7.555710180895403e-05
# Epoch 90: Loss = 7.555710180895403e-05
# 68
# Epoch 0: Loss = 0.22936572134494781
# Epoch 10: Loss = 0.00011754775914596394
# Epoch 20: Loss = 0.00011682356125675142
# Epoch 30: Loss = 0.00011682356125675142
# Epoch 40: Loss = 0.00011682356125675142
# Epoch 50: Loss = 0.00011682356125675142
# Epoch 60: Loss = 0.00011682356125675142
# Epoch 70: Loss = 0.00011682356125675142
# Epoch 80: Loss = 0.00011682356125675142
# Epoch 90: Loss = 0.00011682356125675142
# 69
# Epoch 0: Loss = 0.25072619318962097
# Epoch 10: Loss = nan
# Epoch 20: Loss = nan
# Epoch 30: Loss = nan
# Epoch 40: Loss = nan
# Epoch 50: Loss = nan
# Epoch 60: Loss = nan
# Epoch 70: Loss = nan
# Epoch 80: Loss = nan
# Epoch 90: Loss = nan
# Skipping node 69 due to NaN in predictions
# 70
# Epoch 0: Loss = 0.2569636106491089
# Epoch 10: Loss = 0.0002519029367249459
# Epoch 20: Loss = 0.000116825605800841
# Epoch 30: Loss = 0.000116825605800841
# Epoch 40: Loss = 0.000116825605800841
# Epoch 50: Loss = 0.000116825605800841
# Epoch 60: Loss = 0.000116825605800841
# Epoch 70: Loss = 0.000116825605800841
# Epoch 80: Loss = 0.000116825605800841
# Epoch 90: Loss = 0.000116825605800841
# 71
# Epoch 0: Loss = 0.23223648965358734
# Epoch 10: Loss = 0.009391478262841702
# Epoch 20: Loss = 0.009376210160553455
# Epoch 30: Loss = 0.009376210160553455
# Epoch 40: Loss = 0.009376210160553455
# Epoch 50: Loss = 0.009376210160553455
# Epoch 60: Loss = 0.009376210160553455
# Epoch 70: Loss = 0.009376210160553455
# Epoch 80: Loss = 0.009376210160553455
# Epoch 90: Loss = 0.009376210160553455
# 72
# Epoch 0: Loss = 0.12590613961219788
# Epoch 10: Loss = 0.00012382013665046543
# Epoch 20: Loss = 0.00011682342301355675
# Epoch 30: Loss = 0.00011682342301355675
# Epoch 40: Loss = 0.00011682342301355675
# Epoch 50: Loss = 0.00011682342301355675
# Epoch 60: Loss = 0.00011682342301355675
# Epoch 70: Loss = 0.00011682342301355675
# Epoch 80: Loss = 0.00011682342301355675
# Epoch 90: Loss = 0.00011682342301355675
# 73
# Epoch 0: Loss = 0.2761046886444092
# Epoch 10: Loss = 0.0001185534056276083
# Epoch 20: Loss = 0.00011682489275699481
# Epoch 30: Loss = 0.00011682489275699481
# Epoch 40: Loss = 0.00011682489275699481
# Epoch 50: Loss = 0.00011682489275699481
# Epoch 60: Loss = 0.00011682489275699481
# Epoch 70: Loss = 0.00011682489275699481
# Epoch 80: Loss = 0.00011682489275699481
# Epoch 90: Loss = 0.00011682489275699481
# 74
# Epoch 0: Loss = 0.1834142953157425
# Epoch 10: Loss = 0.00011702068150043488
# Epoch 20: Loss = 0.00011682329932227731
# Epoch 30: Loss = 0.00011682329932227731
# Epoch 40: Loss = 0.00011682329932227731
# Epoch 50: Loss = 0.00011682329932227731
# Epoch 60: Loss = 0.00011682329932227731
# Epoch 70: Loss = 0.00011682329932227731
# Epoch 80: Loss = 0.00011682329932227731
# Epoch 90: Loss = 0.00011682329932227731
# 75
# Epoch 0: Loss = 0.38692745566368103
# Epoch 10: Loss = 0.00014543267025146633
# Epoch 20: Loss = 0.00011682054173434153
# Epoch 30: Loss = 0.00011682054173434153
# Epoch 40: Loss = 0.00011682054173434153
# Epoch 50: Loss = 0.00011682054173434153
# Epoch 60: Loss = 0.00011682054173434153
# Epoch 70: Loss = 0.00011682054173434153
# Epoch 80: Loss = 0.00011682054173434153
# Epoch 90: Loss = 0.00011682054173434153
# 76
# Epoch 0: Loss = 0.2953260838985443
# Epoch 10: Loss = 0.010304323397576809
# Epoch 20: Loss = 0.010304292663931847
# Epoch 30: Loss = 0.010304279625415802
# Epoch 40: Loss = 0.010304279625415802
# Epoch 50: Loss = 0.010304279625415802
# Epoch 60: Loss = 0.010304279625415802
# Epoch 70: Loss = 0.010304279625415802
# Epoch 80: Loss = 0.010304279625415802
# Epoch 90: Loss = 0.010304279625415802
# 77
# Epoch 0: Loss = 0.30535534024238586
# Epoch 10: Loss = 0.0019735742826014757
# Epoch 20: Loss = 0.00011682116746669635
# Epoch 30: Loss = 0.00011682116746669635
# Epoch 40: Loss = 0.00011682116746669635
# Epoch 50: Loss = 0.00011682116746669635
# Epoch 60: Loss = 0.00011682116746669635
# Epoch 70: Loss = 0.00011682116746669635
# Epoch 80: Loss = 0.00011682116746669635
# Epoch 90: Loss = 0.00011682116746669635
# 78
# Epoch 0: Loss = 0.3071530759334564
# Epoch 10: Loss = nan
# Epoch 20: Loss = nan
# Epoch 30: Loss = nan
# Epoch 40: Loss = nan
# Epoch 50: Loss = nan
# Epoch 60: Loss = nan
# Epoch 70: Loss = nan
# Epoch 80: Loss = nan
# Epoch 90: Loss = nan
# Skipping node 78 due to NaN in predictions
# 79
# Epoch 0: Loss = 0.34782370924949646
# Epoch 10: Loss = 0.1610485464334488
# Epoch 20: Loss = 0.00011218828149139881
# Epoch 30: Loss = 5.73696041783478e-08
# Epoch 40: Loss = 5.453317442061234e-08
# Epoch 50: Loss = 5.453317442061234e-08
# Epoch 60: Loss = 5.453317442061234e-08
# Epoch 70: Loss = 5.453317442061234e-08
# Epoch 80: Loss = 5.453317442061234e-08
# Epoch 90: Loss = 5.453317442061234e-08
# 80
# Epoch 0: Loss = 0.23282551765441895
# Epoch 10: Loss = 0.0015424307202920318
# Epoch 20: Loss = 0.0004212488420307636
# Epoch 30: Loss = 0.0004212488420307636
# Epoch 40: Loss = 0.0004212488420307636
# Epoch 50: Loss = 0.0004212488420307636
# Epoch 60: Loss = 0.0004212488420307636
# Epoch 70: Loss = 0.0004212488420307636
# Epoch 80: Loss = 0.0004212488420307636
# Epoch 90: Loss = 0.0004212488420307636
# 81
# Epoch 0: Loss = 0.31988105177879333
# Epoch 10: Loss = 0.00021578681480605155
# Epoch 20: Loss = 7.702920265728608e-05
# Epoch 30: Loss = 7.702199945924804e-05
# Epoch 40: Loss = 7.702199945924804e-05
# Epoch 50: Loss = 7.702199945924804e-05
# Epoch 60: Loss = 7.702199945924804e-05
# Epoch 70: Loss = 7.702199945924804e-05
# Epoch 80: Loss = 7.702199945924804e-05
# Epoch 90: Loss = 7.702199945924804e-05
# 82
# Epoch 0: Loss = 0.3823942244052887
# Epoch 10: Loss = 0.00011776675091823563
# Epoch 20: Loss = 0.00011682225158438087
# Epoch 30: Loss = 0.00011682225158438087
# Epoch 40: Loss = 0.00011682225158438087
# Epoch 50: Loss = 0.00011682225158438087
# Epoch 60: Loss = 0.00011682225158438087
# Epoch 70: Loss = 0.00011682225158438087
# Epoch 80: Loss = 0.00011682225158438087
# Epoch 90: Loss = 0.00011682225158438087
# 83
# Epoch 0: Loss = 0.33710673451423645
# Epoch 10: Loss = 9.053858229890466e-05
# Epoch 20: Loss = 7.681269926251844e-05
# Epoch 30: Loss = 7.675859524169937e-05
# Epoch 40: Loss = 7.672554784221575e-05
# Epoch 50: Loss = 7.669759361306205e-05
# Epoch 60: Loss = 7.668416947126389e-05
# Epoch 70: Loss = 7.6663913205266e-05
# Epoch 80: Loss = 7.664225267944857e-05
# Epoch 90: Loss = 7.661728886887431e-05
# 84
# Epoch 0: Loss = 0.27395376563072205
# Epoch 10: Loss = 2.067441420875744e+28
# Epoch 20: Loss = 2.067441420875744e+28
# Epoch 30: Loss = 2.067441420875744e+28
# Epoch 40: Loss = 2.067441420875744e+28
# Epoch 50: Loss = 2.067441420875744e+28
# Epoch 60: Loss = 2.067441420875744e+28
# Epoch 70: Loss = 2.067441420875744e+28
# Epoch 80: Loss = 2.067441420875744e+28
# Epoch 90: Loss = 2.067441420875744e+28
# 85
# Epoch 0: Loss = 0.17030847072601318
# Epoch 10: Loss = 0.0003959271125495434
# Epoch 20: Loss = 7.709314377279952e-05
# Epoch 30: Loss = 7.706620817771181e-05
# Epoch 40: Loss = 7.706134783802554e-05
# Epoch 50: Loss = 7.705769530730322e-05
# Epoch 60: Loss = 7.705688767600805e-05
# Epoch 70: Loss = 7.705688767600805e-05
# Epoch 80: Loss = 7.705688767600805e-05
# Epoch 90: Loss = 7.705688767600805e-05
# 86
# Epoch 0: Loss = 0.31193581223487854
# Epoch 10: Loss = 0.0018559112213551998
# Epoch 20: Loss = 0.00011682447075145319
# Epoch 30: Loss = 0.00011682447075145319
# Epoch 40: Loss = 0.00011682447075145319
# Epoch 50: Loss = 0.00011682447075145319
# Epoch 60: Loss = 0.00011682447075145319
# Epoch 70: Loss = 0.00011682447075145319
# Epoch 80: Loss = 0.00011682447075145319
# Epoch 90: Loss = 0.00011682447075145319
# 87
# Epoch 0: Loss = 0.28125616908073425
# Epoch 10: Loss = 0.0001093654936994426
# Epoch 20: Loss = 7.555604679509997e-05
# Epoch 30: Loss = 7.555604679509997e-05
# Epoch 40: Loss = 7.555604679509997e-05
# Epoch 50: Loss = 7.555604679509997e-05
# Epoch 60: Loss = 7.555604679509997e-05
# Epoch 70: Loss = 7.555604679509997e-05
# Epoch 80: Loss = 7.555604679509997e-05
# Epoch 90: Loss = 7.555604679509997e-05
# 88
# Epoch 0: Loss = 0.24502195417881012
# Epoch 10: Loss = nan
# Epoch 20: Loss = nan
# Epoch 30: Loss = nan
# Epoch 40: Loss = nan
# Epoch 50: Loss = nan
# Epoch 60: Loss = nan
# Epoch 70: Loss = nan
# Epoch 80: Loss = nan
# Epoch 90: Loss = nan
# Skipping node 88 due to NaN in predictions
# 89
# Epoch 0: Loss = 0.3126024007797241
# Epoch 10: Loss = 0.0002264034264953807
# Epoch 20: Loss = 0.00011682025069603696
# Epoch 30: Loss = 0.00011682025069603696
# Epoch 40: Loss = 0.00011682025069603696
# Epoch 50: Loss = 0.00011682025069603696
# Epoch 60: Loss = 0.00011682025069603696
# Epoch 70: Loss = 0.00011682025069603696
# Epoch 80: Loss = 0.00011682025069603696
# Epoch 90: Loss = 0.00011682025069603696
# 90
# Epoch 0: Loss = 0.20415298640727997
# Epoch 10: Loss = 0.0010220551630482078
# Epoch 20: Loss = 8.370424620807171e-05
# Epoch 30: Loss = 8.370455907424912e-05
# Epoch 40: Loss = 8.370455907424912e-05
# Epoch 50: Loss = 8.370455907424912e-05
# Epoch 60: Loss = 8.370455907424912e-05
# Epoch 70: Loss = 8.370455907424912e-05
# Epoch 80: Loss = 8.370455907424912e-05
# Epoch 90: Loss = 8.370455907424912e-05
# 91
# Epoch 0: Loss = 0.27164798974990845
# Epoch 10: Loss = 0.00015814216749276966
# Epoch 20: Loss = 0.00011682452168315649
# Epoch 30: Loss = 0.00011682436888804659
# Epoch 40: Loss = 0.00011682436888804659
# Epoch 50: Loss = 0.00011682436888804659
# Epoch 60: Loss = 0.00011682436888804659
# Epoch 70: Loss = 0.00011682436888804659
# Epoch 80: Loss = 0.00011682436888804659
# Epoch 90: Loss = 0.00011682436888804659
# 92
# Epoch 0: Loss = 0.2562498450279236
# Epoch 10: Loss = 0.004091206938028336
# Epoch 20: Loss = 0.00011682920739986002
# Epoch 30: Loss = 0.00011682512558763847
# Epoch 40: Loss = 0.00011682512558763847
# Epoch 50: Loss = 0.00011682512558763847
# Epoch 60: Loss = 0.00011682512558763847
# Epoch 70: Loss = 0.00011682512558763847
# Epoch 80: Loss = 0.00011682512558763847
# Epoch 90: Loss = 0.00011682512558763847
# 93
# Epoch 0: Loss = 0.5665375590324402
# Epoch 10: Loss = 0.0017051901668310165
# Epoch 20: Loss = 0.00011682132026180625
# Epoch 30: Loss = 0.00011682132026180625
# Epoch 40: Loss = 0.00011682132026180625
# Epoch 50: Loss = 0.00011682132026180625
# Epoch 60: Loss = 0.00011682132026180625
# Epoch 70: Loss = 0.00011682132026180625
# Epoch 80: Loss = 0.00011682132026180625
# Epoch 90: Loss = 0.00011682132026180625
# 94
# Epoch 0: Loss = 0.28512322902679443
# Epoch 10: Loss = 0.004290663171559572
# Epoch 20: Loss = 0.00011821624502772465
# Epoch 30: Loss = 0.00011682444164762273
# Epoch 40: Loss = 0.00011682444164762273
# Epoch 50: Loss = 0.00011682444164762273
# Epoch 60: Loss = 0.00011682444164762273
# Epoch 70: Loss = 0.00011682444164762273
# Epoch 80: Loss = 0.00011682444164762273
# Epoch 90: Loss = 0.00011682444164762273
# 95
# Epoch 0: Loss = 0.27422693371772766
# Epoch 10: Loss = 0.0009785600705072284
# Epoch 20: Loss = 0.00011682981858029962
# Epoch 30: Loss = 0.00011682448530336842
# Epoch 40: Loss = 0.00011682448530336842
# Epoch 50: Loss = 0.00011682448530336842
# Epoch 60: Loss = 0.00011682448530336842
# Epoch 70: Loss = 0.00011682448530336842
# Epoch 80: Loss = 0.00011682448530336842
# Epoch 90: Loss = 0.00011682448530336842
# 96
# Epoch 0: Loss = 0.3136734664440155
# Epoch 10: Loss = 0.000787799886893481
# Epoch 20: Loss = 8.606700430391356e-05
# Epoch 30: Loss = 8.606138726463541e-05
# Epoch 40: Loss = 8.606138726463541e-05
# Epoch 50: Loss = 8.606138726463541e-05
# Epoch 60: Loss = 8.606138726463541e-05
# Epoch 70: Loss = 8.606138726463541e-05
# Epoch 80: Loss = 8.606138726463541e-05
# Epoch 90: Loss = 8.606138726463541e-05
# 97
# Epoch 0: Loss = 0.19461791217327118
# Epoch 10: Loss = 9.524593042442575e-05
# Epoch 20: Loss = 8.370302384719253e-05
# Epoch 30: Loss = 8.370302384719253e-05
# Epoch 40: Loss = 8.370302384719253e-05
# Epoch 50: Loss = 8.370302384719253e-05
# Epoch 60: Loss = 8.370302384719253e-05
# Epoch 70: Loss = 8.370302384719253e-05
# Epoch 80: Loss = 8.370302384719253e-05
# Epoch 90: Loss = 8.370302384719253e-05
# 98
# Epoch 0: Loss = 0.3158433735370636
# Epoch 10: Loss = 0.00010106965783052146
# Epoch 20: Loss = 8.017567779461388e-06
# Epoch 30: Loss = 5.988878370999373e-08
# Epoch 40: Loss = 5.6874515763638556e-08
# Epoch 50: Loss = 5.6874515763638556e-08
# Epoch 60: Loss = 5.6874515763638556e-08
# Epoch 70: Loss = 5.6874515763638556e-08
# Epoch 80: Loss = 5.6874515763638556e-08
# Epoch 90: Loss = 5.6874515763638556e-08
# 99
# Epoch 0: Loss = 0.287280797958374
# Epoch 10: Loss = 0.0009874086827039719
# Epoch 20: Loss = 0.00011682420154102147
# Epoch 30: Loss = 0.00011682263721013442
# Epoch 40: Loss = 0.00011682263721013442
# Epoch 50: Loss = 0.00011682263721013442
# Epoch 60: Loss = 0.00011682263721013442
# Epoch 70: Loss = 0.00011682263721013442
# Epoch 80: Loss = 0.00011682263721013442
# Epoch 90: Loss = 0.00011682263721013442
# 100
# Epoch 0: Loss = 0.33322152495384216
# Epoch 10: Loss = nan
# Epoch 20: Loss = nan
# Epoch 30: Loss = nan
# Epoch 40: Loss = nan
# Epoch 50: Loss = nan
# Epoch 60: Loss = nan
# Epoch 70: Loss = nan
# Epoch 80: Loss = nan
# Epoch 90: Loss = nan
# Skipping node 100 due to NaN in predictions
# 101
# Epoch 0: Loss = 0.41126224398612976
# Epoch 10: Loss = 0.0017123980214819312
# Epoch 20: Loss = 0.00010641731932992116
# Epoch 30: Loss = 0.0001064102616510354
# Epoch 40: Loss = 0.00010640643449733034
# Epoch 50: Loss = 0.00010640397522365674
# Epoch 60: Loss = 0.00010639846004778519
# Epoch 70: Loss = 0.00010639870743034407
# Epoch 80: Loss = 0.00010639870743034407
# Epoch 90: Loss = 0.00010639870743034407
# 102
# Epoch 0: Loss = 0.2718392312526703
# Epoch 10: Loss = 0.0001076761182048358
# Epoch 20: Loss = 8.370424620807171e-05
# Epoch 30: Loss = 8.370424620807171e-05
# Epoch 40: Loss = 8.370424620807171e-05
# Epoch 50: Loss = 8.370424620807171e-05
# Epoch 60: Loss = 8.370424620807171e-05
# Epoch 70: Loss = 8.370424620807171e-05
# Epoch 80: Loss = 8.370424620807171e-05
# Epoch 90: Loss = 8.370424620807171e-05
# 103
# Epoch 0: Loss = 0.19933520257472992
# Epoch 10: Loss = 0.0003103801573161036
# Epoch 20: Loss = 5.803612523891388e-08
# Epoch 30: Loss = 5.535537539458346e-08
# Epoch 40: Loss = 5.535537539458346e-08
# Epoch 50: Loss = 5.535537539458346e-08
# Epoch 60: Loss = 5.535537539458346e-08
# Epoch 70: Loss = 5.535537539458346e-08
# Epoch 80: Loss = 5.535537539458346e-08
# Epoch 90: Loss = 5.535537539458346e-08
# 104
# Epoch 0: Loss = 0.27908018231391907
# Epoch 10: Loss = 0.00031626326381228864
# Epoch 20: Loss = 0.0001062092705979012
# Epoch 30: Loss = 0.0001062092705979012
# Epoch 40: Loss = 0.0001062092705979012
# Epoch 50: Loss = 0.0001062092705979012
# Epoch 60: Loss = 0.0001062092705979012
# Epoch 70: Loss = 0.0001062092705979012
# Epoch 80: Loss = 0.0001062092705979012
# Epoch 90: Loss = 0.0001062092705979012
# 105
# Epoch 0: Loss = 0.2287251502275467
# Epoch 10: Loss = 0.00032707245554775
# Epoch 20: Loss = 0.00010620972170727327
# Epoch 30: Loss = 0.00010620995453791693
# Epoch 40: Loss = 0.00010620995453791693
# Epoch 50: Loss = 0.00010620995453791693
# Epoch 60: Loss = 0.00010620995453791693
# Epoch 70: Loss = 0.00010620995453791693
# Epoch 80: Loss = 0.00010620995453791693
# Epoch 90: Loss = 0.00010620995453791693
# 106
# Epoch 0: Loss = 0.42295345664024353
# Epoch 10: Loss = 0.023554792627692223
# Epoch 20: Loss = nan
# Epoch 30: Loss = nan
# Epoch 40: Loss = nan
# Epoch 50: Loss = nan
# Epoch 60: Loss = nan
# Epoch 70: Loss = nan
# Epoch 80: Loss = nan
# Epoch 90: Loss = nan
# Skipping node 106 due to NaN in predictions
# 107
# Epoch 0: Loss = 0.28665050864219666
# Epoch 10: Loss = 0.0009347847080789506
# Epoch 20: Loss = 0.00011682407784974203
# Epoch 30: Loss = 0.00011682599870255217
# Epoch 40: Loss = 0.00011682599870255217
# Epoch 50: Loss = 0.00011682599870255217
# Epoch 60: Loss = 0.00011682599870255217
# Epoch 70: Loss = 0.00011682599870255217
# Epoch 80: Loss = 0.00011682599870255217
# Epoch 90: Loss = 0.00011682599870255217
# 108
# Epoch 0: Loss = 0.288077712059021
# Epoch 10: Loss = 0.8404601216316223
# Epoch 20: Loss = 0.0004212496569380164
# Epoch 30: Loss = 0.0004212496569380164
# Epoch 40: Loss = 0.0004212496569380164
# Epoch 50: Loss = 0.0004212496569380164
# Epoch 60: Loss = 0.0004212496569380164
# Epoch 70: Loss = 0.0004212496569380164
# Epoch 80: Loss = 0.0004212496569380164
# Epoch 90: Loss = 0.0004212496569380164
# 109
# Epoch 0: Loss = 0.4006243944168091
# Epoch 10: Loss = nan
# Epoch 20: Loss = nan
# Epoch 30: Loss = nan
# Epoch 40: Loss = nan
# Epoch 50: Loss = nan
# Epoch 60: Loss = nan
# Epoch 70: Loss = nan
# Epoch 80: Loss = nan
# Epoch 90: Loss = nan
# Skipping node 109 due to NaN in predictions
# 110
# Epoch 0: Loss = 0.24682068824768066
# Epoch 10: Loss = 0.00016648414020892233
# Epoch 20: Loss = 0.00011682496551657096
# Epoch 30: Loss = 0.00011682624608511105
# Epoch 40: Loss = 0.00011682624608511105
# Epoch 50: Loss = 0.00011682624608511105
# Epoch 60: Loss = 0.00011682624608511105
# Epoch 70: Loss = 0.00011682624608511105
# Epoch 80: Loss = 0.00011682624608511105
# Epoch 90: Loss = 0.00011682624608511105
# 111
# Epoch 0: Loss = 0.25314635038375854
# Epoch 10: Loss = 0.0009841684950515628
# Epoch 20: Loss = 0.00011683392222039402
# Epoch 30: Loss = 0.00011682465992635116
# Epoch 40: Loss = 0.00011682465992635116
# Epoch 50: Loss = 0.00011682465992635116
# Epoch 60: Loss = 0.00011682465992635116
# Epoch 70: Loss = 0.00011682465992635116
# Epoch 80: Loss = 0.00011682465992635116
# Epoch 90: Loss = 0.00011682465992635116
# 112
# Epoch 0: Loss = 0.3226119577884674
# Epoch 10: Loss = 0.011721823364496231
# Epoch 20: Loss = 0.00011683018965413794
# Epoch 30: Loss = 0.00011682224430842325
# Epoch 40: Loss = 0.00011682224430842325
# Epoch 50: Loss = 0.00011682224430842325
# Epoch 60: Loss = 0.00011682224430842325
# Epoch 70: Loss = 0.00011682224430842325
# Epoch 80: Loss = 0.00011682224430842325
# Epoch 90: Loss = 0.00011682224430842325
# 113
# Epoch 0: Loss = 0.29172495007514954
# Epoch 10: Loss = 0.00018920244474429637
# Epoch 20: Loss = 0.00011682475451380014
# Epoch 30: Loss = 0.00011682227341225371
# Epoch 40: Loss = 0.00011682227341225371
# Epoch 50: Loss = 0.00011682227341225371
# Epoch 20: Loss = 0.0001168239105027169
# Epoch 30: Loss = 0.0001168239105027169
# Epoch 40: Loss = 0.0001168239105027169
# Epoch 50: Loss = 0.0001168239105027169
# Epoch 60: Loss = 0.0001168239105027169
# Epoch 70: Loss = 0.0001168239105027169
# Epoch 80: Loss = 0.0001168239105027169
# Epoch 90: Loss = 0.0001168239105027169
# 121
# Epoch 0: Loss = 0.13968665897846222
# Epoch 10: Loss = 0.0027308061253279448
# Epoch 20: Loss = 1.893375497274974e-06
# Epoch 30: Loss = 5.694057847449585e-08
# Epoch 40: Loss = 5.654443668845488e-08
# Epoch 50: Loss = 5.654443668845488e-08
# Epoch 60: Loss = 5.654443668845488e-08
# Epoch 70: Loss = 5.654443668845488e-08
# Epoch 80: Loss = 5.654443668845488e-08
# Epoch 90: Loss = 5.654443668845488e-08
# 122
# Epoch 0: Loss = 0.338694304227829
# Epoch 10: Loss = 0.002385555999353528
# Epoch 20: Loss = nan
# Epoch 30: Loss = nan
# Epoch 40: Loss = nan
# Epoch 50: Loss = nan
# Epoch 60: Loss = nan
# Epoch 70: Loss = nan
# Epoch 80: Loss = nan
# Epoch 90: Loss = nan
# Skipping node 122 due to NaN in predictions
# 123
# Epoch 0: Loss = 0.2899121940135956
# Epoch 10: Loss = 0.0015773318009451032
# Epoch 20: Loss = 0.000421251286752522
# Epoch 30: Loss = 0.0004212464264128357
# Epoch 40: Loss = 0.0004212464264128357
# Epoch 50: Loss = 0.0004212464264128357
# Epoch 60: Loss = 0.0004212464264128357
# Epoch 70: Loss = 0.0004212464264128357
# Epoch 80: Loss = 0.0004212464264128357
# Epoch 90: Loss = 0.0004212464264128357
# 124
# Epoch 0: Loss = 0.316423624753952
# Epoch 10: Loss = 0.002239733934402466
# Epoch 20: Loss = 8.370415162062272e-05
# Epoch 30: Loss = 8.370294381165877e-05
# Epoch 40: Loss = 8.370294381165877e-05
# Epoch 50: Loss = 8.370294381165877e-05
# Epoch 60: Loss = 8.370294381165877e-05
# Epoch 70: Loss = 8.370294381165877e-05
# Epoch 80: Loss = 8.370294381165877e-05
# Epoch 90: Loss = 8.370294381165877e-05
# 125
# Epoch 0: Loss = 0.3062780499458313
# Epoch 10: Loss = 0.0003887884085997939
# Epoch 20: Loss = 3.0081748718657764e-06
# Epoch 30: Loss = 5.563408578268536e-08
# Epoch 40: Loss = 5.519306611745378e-08
# Epoch 50: Loss = 5.519306611745378e-08
# Epoch 60: Loss = 5.519306611745378e-08
# Epoch 70: Loss = 5.519306611745378e-08
# Epoch 80: Loss = 5.519306611745378e-08
# Epoch 90: Loss = 5.519306611745378e-08
# 126
# Epoch 0: Loss = 0.2374822348356247
# Epoch 10: Loss = nan
# Epoch 20: Loss = nan
# Epoch 30: Loss = nan
# Epoch 40: Loss = nan
# Epoch 50: Loss = nan
# Epoch 60: Loss = nan
# Epoch 70: Loss = nan
# Epoch 80: Loss = nan
# Epoch 90: Loss = nan
# Skipping node 126 due to NaN in predictions
# 127
# Epoch 0: Loss = 0.19693340361118317
# Epoch 10: Loss = 0.00012604908260982484
# Epoch 70: Loss = 1.3222876987128984e-05
# Epoch 80: Loss = 1.3222876987128984e-05
# Epoch 90: Loss = 1.3222876987128984e-05
# 7550
# Epoch 0: Loss = 0.29517611861228943
# Epoch 10: Loss = 0.004069760907441378
# Epoch 20: Loss = 0.0004079726932104677
# Epoch 30: Loss = 6.134590876172297e-06
# Epoch 40: Loss = 6.13141719441046e-06
# Epoch 50: Loss = 6.13141719441046e-06
# Epoch 60: Loss = 6.13141719441046e-06
# Epoch 70: Loss = 6.13141719441046e-06
# Epoch 80: Loss = 6.13141719441046e-06
# Epoch 90: Loss = 6.13141719441046e-06
# 7600
# Epoch 0: Loss = 0.222089484333992
# Epoch 10: Loss = 0.0007695825188420713
# Epoch 20: Loss = 9.237951417162549e-06
# Epoch 30: Loss = 9.235503966920078e-06
# Epoch 40: Loss = 9.235503966920078e-06
# Epoch 50: Loss = 9.235503966920078e-06
# Epoch 60: Loss = 9.235503966920078e-06
# Epoch 70: Loss = 9.235503966920078e-06
# Epoch 80: Loss = 9.235503966920078e-06
# Epoch 90: Loss = 9.235503966920078e-06
# 7650
# Epoch 0: Loss = 0.32878684997558594
# Epoch 10: Loss = 0.0014254129491746426
# Epoch 20: Loss = 0.00012558257731143385
# Epoch 30: Loss = 4.9289119488094e-06
# Epoch 40: Loss = 4.928410817228723e-06
# Epoch 50: Loss = 4.928410817228723e-06
# Epoch 60: Loss = 4.928410817228723e-06
# Epoch 70: Loss = 4.928410817228723e-06
# Epoch 80: Loss = 4.928410817228723e-06
# Epoch 90: Loss = 4.928410817228723e-06
# 7700
# Epoch 0: Loss = 0.32213857769966125
# Epoch 10: Loss = 0.003684890689328313
# Epoch 20: Loss = 5.795352626591921e-05
# Epoch 30: Loss = 1.3501201465260237e-05
# Epoch 40: Loss = 1.3500191016646568e-05
# Epoch 50: Loss = 1.3500191016646568e-05
# Epoch 60: Loss = 1.3500191016646568e-05
# Epoch 70: Loss = 1.3500191016646568e-05
# Epoch 80: Loss = 1.3500191016646568e-05
# Epoch 90: Loss = 1.3500191016646568e-05
# 7750
# Epoch 0: Loss = 0.1901121586561203
# Epoch 10: Loss = 0.00034333067014813423
# Epoch 20: Loss = 7.800397725077346e-06
# Epoch 30: Loss = 7.794701559760142e-06
# Epoch 40: Loss = 7.793129043420777e-06
# Epoch 50: Loss = 7.793417353241239e-06
# Epoch 60: Loss = 7.792210453771986e-06
# Epoch 70: Loss = 7.790506060700864e-06
# Epoch 80: Loss = 7.789312803652138e-06
# Epoch 90: Loss = 7.788301445543766e-06
# 7800
# Epoch 0: Loss = 0.2912697196006775
# Epoch 10: Loss = 0.0029509123414754868
# Epoch 20: Loss = 0.0002475735091138631
# Epoch 30: Loss = 1.3481687346938998e-05
# Epoch 40: Loss = 1.3481261703418568e-05
# Epoch 50: Loss = 1.3481261703418568e-05
# Epoch 60: Loss = 1.3481261703418568e-05
# Epoch 70: Loss = 1.3481261703418568e-05
# Epoch 80: Loss = 1.3481261703418568e-05
# Epoch 90: Loss = 1.3481261703418568e-05
# 7850
# Epoch 0: Loss = 0.32512637972831726
# Epoch 10: Loss = 0.00047806440852582455
# Epoch 20: Loss = 2.5148476652248064e-06
# Epoch 30: Loss = 1.8055276314044022e-06
# Epoch 40: Loss = 1.8057459101328277e-06
# Epoch 50: Loss = 1.8057459101328277e-06
# Epoch 60: Loss = 1.8057459101328277e-06
# Epoch 70: Loss = 1.8057459101328277e-06
# Epoch 80: Loss = 1.8057459101328277e-06
# Epoch 90: Loss = 1.8057459101328277e-06
# 7900
# Epoch 0: Loss = 0.04000662639737129
# Epoch 10: Loss = 0.00025029489188455045
# Epoch 20: Loss = 8.682495717948768e-06
# Epoch 30: Loss = 8.680723112775013e-06
# Epoch 40: Loss = 8.680723112775013e-06
# Epoch 50: Loss = 8.680723112775013e-06
# Epoch 60: Loss = 8.680723112775013e-06
# Epoch 70: Loss = 8.680723112775013e-06
# Epoch 80: Loss = 8.680723112775013e-06
# Epoch 90: Loss = 8.680723112775013e-06
# 7950
# Epoch 0: Loss = 0.02218584530055523
# Epoch 10: Loss = 0.00027232550201006234
# Epoch 20: Loss = 1.1839912076538894e-05
# Epoch 30: Loss = 2.454903551551979e-06
# Epoch 40: Loss = 2.234897920061485e-06
# Epoch 50: Loss = 2.233843360954779e-06
# Epoch 60: Loss = 2.233843360954779e-06
# Epoch 70: Loss = 2.233843360954779e-06
# Epoch 80: Loss = 2.233843360954779e-06
# Epoch 90: Loss = 2.233843360954779e-06
# 8000
# Epoch 0: Loss = 0.2486303448677063
# Epoch 10: Loss = 0.0008307509706355631
# Epoch 20: Loss = 8.09787252364913e-06
# Epoch 30: Loss = 2.1794414806208806e-06
# Epoch 40: Loss = 2.1736250346293673e-06
# Epoch 50: Loss = 2.1736250346293673e-06
# Epoch 60: Loss = 2.1736250346293673e-06
# Epoch 70: Loss = 2.1736250346293673e-06
# Epoch 80: Loss = 2.1736250346293673e-06
# Epoch 90: Loss = 2.1736250346293673e-06

# %% [markdown]
# ## Creating the video

# %%
fontsize= 18
ticksize = 14
figsize = (10, 5)
params = {'font.family':'serif',
    "figure.figsize":figsize,
    'figure.dpi': 80,
    'figure.edgecolor': 'k',
    'font.size': fontsize,
    'axes.labelsize': fontsize,
    'axes.titlesize': fontsize,
    'xtick.labelsize': ticksize,
    'ytick.labelsize': ticksize
}
plt.rcParams.update(params)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import imageio.v2 as imageio  # use v2 API to avoid warning

# %%
filenames = []

for i in range(results_array.shape[0]):
    y_hat = results_array[i,:]
    plt.scatter(x_train,y_train, color = "r", label = "Training Data")
    plt.plot(x_test, y_hat, color = "b")
    plt.xlabel(r"$X$")
    plt.ylabel(r"$Y$")
    plt.ylim(-2.0, 3)
    plt.text(3, 3.2, f"Number of Parameters: {num_params_array[i]}", ha='center', fontsize=14)  # <--- epoch below suptitle
    plt.tight_layout()
    
    filename = f'{i}.png'
    filenames.append(filename)

    # save frame
    plt.savefig(filename)
    plt.close()# build gif
with imageio.get_writer('smooth_interpolation.gif', mode='I') as writer:
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)
        
# Remove files
for filename in set(filenames):
    os.remove(filename)
